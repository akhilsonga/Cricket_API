# %%
import re
from bs4 import BeautifulSoup
import urllib
url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
webpage_content = urllib.request.urlopen(url).read()
data = BeautifulSoup(webpage_content, 'html.parser')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            #print(type(i))
            commentry.append(i.get_text())
            j = i.parent
            b = j.previous_sibling
            #print(b)
            sp1 = b.find_all("span")
            for a in sp1:
                sp2 = a.find_all("span")
                for b in sp2:
                    runs.append(a.get_text())
                            
print(runs) 
print("\n") 
print(commentry)
# Out:
# ['Sam Curran to Santner, 1 run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, 2 runs', 'Sam Curran to Santner, 1 wide', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Sodhi, no run', 'Woakes to Santner, SIX runs', 'Woakes to Santner, 1 wide', 'Woakes to Santner, 2 runs', 'Woakes to Santner, 2 runs', 'Woakes to Sodhi, 1 leg bye', 'Woakes to Santner, 1 run', 'Woakes to Sodhi, 1 run', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Santner, 1 run', 'Sam Curran to Sodhi, 3 runs', 'Sam Curran to Phillips, OUT', 'Sam Curran to Santner, 1 run', 'Sam Curran to Phillips, 3 runs']
#
#
# ['right on the mark again from Curran, bending back in on a yorker length, clipped to long-on, and England win by 20 runs', 'bouncer, well directed, following the batter and rising sharply off the deck. More precious dots to improve the NRR for England', "brilliant blockhole bowling from Curran, another inswinging yorker, curling into the left-hander's toes", 'inswinger, into the legs, cuffed to long-on, and back for two more', "fired in fuller, Santner walks across his stumps, and England review! Looked like the umpire was going to signal wide, but there might have been a tickle through to the keeper. Doesn't look like it... and no pad either. Wide it is!", 'outside off, into the pitch, back of a length, clawed to midwicket', "ghosts past the outside edge, curling away on the full length, can't connect on the slapped drive. A precious dot, given that NRR is as important as the win now", "sits back in the crease, and slams a six up and over long-on! A useful strike from Santner, just keeps New Zealand's faint hopes alive. Woakes is frustrated, but that's a mighty stint all the same", "too wide this time, outside the batter's arc", 'back of a length, tight across the left-hander, another attempted pull but rolls out towards long-on.', 'crashed on the up, full length outside off, and picked up in the deep', 'good aggression from Woakes, pace on this time, into the pitch as the batter advances and wears his attempted pull in the ribs', 'pushed across the left-hander on the full length, hacked out to deep point and just the single, as the rate leaps towards four a ball', 'thumped through the line, but no timing, another single to mid-on', "eased down the ground, another exceptional screw-turning over. It's 20 an over now, and New Zealand need snookers", 'superb from Curran, sees the batter shaping to leg, follows him with the inswinger, and they can only pick off the cramped single to mid-on', 'stabbed off the ribs, up and over backward square, Rashid rushes back at the rope and drags it back well', 'Walloped high through the line, and Jordan pouches another! That, surely, is the game for England! Phillips had to put bat through ball, but the tricksy angle and pace off the pitch scuppers his timing. The super-sub is back on the edge of the rope and makes no mistake!', 'short from Curran, sticking in the pitch as Santner leans back on a pull to midwicket', "outside off, slams the drive with excellent placement, but Brook tracks it from deep cover and flings out a hand to intercept! Brilliant commitment to save a single. Still, that's the three a ball needed..."]

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
 
# create instance of Chrome webdriver
driver=webdriver.Chrome(ChromeDriverManager().install())
 
#url
#driver.get("www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
#maximize window
#driver.maximize_window()
 
#scroll by pixel
for i in range(10):
    driver.execute_script("window.scrollBy(0,900)","")
    time.sleep(3)
    i = i+1
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_1640\1621037300.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
from bs4 import BeautifulSoup
import urllib
 
# create instance of Chrome webdriver
driver=webdriver.Chrome(ChromeDriverManager().install())
 
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
for i in range(10):
    driver.execute_script("window.scrollBy(0,700)","")
    time.sleep(3)
    i = i+1
page_source = driver.page_source

# url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
# webpage_content = urllib.request.urlopen(url).read()
# data = BeautifulSoup(webpage_content, 'html.parser')
data = BeautifulSoup(page_source, 'lxml')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            #print(type(i))
            commentry.append(i.get_text())
            j = i.parent
            b = j.previous_sibling
            #print(b)
            sp1 = b.find_all("span")
            for a in sp1:
                sp2 = a.find_all("span")
                for b in sp2:
                    runs.append(a.get_text())
                            
print(runs)
len(runs)
print("\n") 
print(commentry)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_1640\19105574.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# ['Sam Curran to Santner, 1 run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, 2 runs', 'Sam Curran to Santner, 1 wide', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Sodhi, no run', 'Woakes to Santner, SIX runs', 'Woakes to Santner, 1 wide', 'Woakes to Santner, 2 runs', 'Woakes to Santner, 2 runs', 'Woakes to Sodhi, 1 leg bye', 'Woakes to Santner, 1 run', 'Woakes to Sodhi, 1 run', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Santner, 1 run', 'Sam Curran to Sodhi, 3 runs', 'Sam Curran to Phillips, OUT', 'Sam Curran to Santner, 1 run', 'Sam Curran to Phillips, 3 runs', 'Woakes to Mitchell, OUT', 'Woakes to Phillips, 1 run', 'Woakes to Phillips, no run', 'Woakes to Mitchell, 1 run', 'Woakes to Mitchell, 2 runs', 'Woakes to Phillips, 1 run', 'Wood to Mitchell, no run', 'Wood to Mitchell, no run', 'Wood to Neesham, OUT', 'Wood to Neesham, 2 runs', 'Wood to Phillips, 1 run', 'Wood to Phillips, no run', 'Stokes to Neesham, FOUR runs', 'Stokes to Williamson, OUT', 'Stokes to Phillips, 1 run', 'Stokes to Phillips, no run', 'Stokes to Phillips, FOUR runs', 'Stokes to Williamson, 1 run', 'Rashid to Williamson, 1 run', 'Rashid to Phillips, 1 run', 'Rashid to Phillips, 2 runs', 'Rashid to Phillips, SIX runs', 'Rashid to Phillips, SIX runs', 'Rashid to Williamson, 1 run', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Phillips, no run', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Williamson, 1 run', 'Sam Curran to Phillips, 2 wide', 'Sam Curran to Williamson, 1 run']
#
#
# ['right on the mark again from Curran, bending back in on a yorker length, clipped to long-on, and England win by 20 runs', 'bouncer, well directed, following the batter and rising sharply off the deck. More precious dots to improve the NRR for England', "brilliant blockhole bowling from Curran, another inswinging yorker, curling into the left-hander's toes", 'inswinger, into the legs, cuffed to long-on, and back for two more', "fired in fuller, Santner walks across his stumps, and England review! Looked like the umpire was going to signal wide, but there might have been a tickle through to the keeper. Doesn't look like it... and no pad either. Wide it is!", 'outside off, into the pitch, back of a length, clawed to midwicket', "ghosts past the outside edge, curling away on the full length, can't connect on the slapped drive. A precious dot, given that NRR is as important as the win now", "sits back in the crease, and slams a six up and over long-on! A useful strike from Santner, just keeps New Zealand's faint hopes alive. Woakes is frustrated, but that's a mighty stint all the same", "too wide this time, outside the batter's arc", 'back of a length, tight across the left-hander, another attempted pull but rolls out towards long-on.', 'crashed on the up, full length outside off, and picked up in the deep', 'good aggression from Woakes, pace on this time, into the pitch as the batter advances and wears his attempted pull in the ribs', 'pushed across the left-hander on the full length, hacked out to deep point and just the single, as the rate leaps towards four a ball', 'thumped through the line, but no timing, another single to mid-on', "eased down the ground, another exceptional screw-turning over. It's 20 an over now, and New Zealand need snookers", 'superb from Curran, sees the batter shaping to leg, follows him with the inswinger, and they can only pick off the cramped single to mid-on', 'stabbed off the ribs, up and over backward square, Rashid rushes back at the rope and drags it back well', 'Walloped high through the line, and Jordan pouches another! That, surely, is the game for England! Phillips had to put bat through ball, but the tricksy angle and pace off the pitch scuppers his timing. The super-sub is back on the edge of the rope and makes no mistake!', 'short from Curran, sticking in the pitch as Santner leans back on a pull to midwicket', "outside off, slams the drive with excellent placement, but Brook tracks it from deep cover and flings out a hand to intercept! Brilliant commitment to save a single. Still, that's the three a ball needed...", "Slower ball, launched through the line but Jordan's there at long-on! What a brilliant over from Woakes, into the pitch once again, just back of a length, confounding Mitchell's timing as he swung for the hills. Suddenly, it's Phillips or bust for New Zealand!", 'pace off again, short and into the ribs, another muscular fling of the bat but only a single to backward square', 'another outstanding cutter, line and length, gripping the surface, turning the screw, jabbed back through the line for a precious dot', "slower ball, into the pitch, brings out the pull but it's a long way to the rope and just another single", 'back of a length, wide on the crease again, another tuck behind square and though Curran releases quickly, Buttler has to stretch to flick it back onto the stumps. Safely home', 'hits the pitch with the cutter, wide of the crease, defended out to the off side', 'whips through the pull, but misses! Wood has delivered with a priceless over. One more up his sleeve to drag England back into this contest', 'fast and full, outside off, angled bat on the defensive push to point', "pulled... straight to Curran at deep midwicket! The pace makes the breakthrough! Short, outside off, Neesham rocks back, targetting the longer side of the ground, but can't get hold of it. Curran rushes in, steadies himself, and gees up the crowd as England continue to battle back!", 'round  ...

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.5-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm in c:\users\akhil\anaconda3\lib\site-packages (from webdriver-manager) (4.64.0)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in c:\users\akhil\anaconda3\lib\site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: packaging in c:\users\akhil\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\akhil\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\akhil\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\akhil\anaconda3\lib\site-packages (from requests->webdriver-manager) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\akhil\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akhil\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.24)
# Requirement already satisfied: colorama in c:\users\akhil\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-0.21.0 webdriver-manager-3.8.5

# %%
print(len(runs))
print(len(commentry))
# Out:
# 51
# 51

# %%
import re
from bs4 import BeautifulSoup
import urllib




url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
webpage_content = urllib.request.urlopen(url).read()
data = BeautifulSoup(webpage_content, 'html.parser')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            j = i.parent
            j = j.parent
            j = j.parent
            j = j.parent
            j = j.parent
            k = j.find("span").text
            print(k)
            
            #print(j)
            print("____________")
            #print(type(i))
# Out:
# 19.6
# ____________
# 19.5
# ____________
# 19.4
# ____________
# 19.3
# ____________
# 19.3
# ____________
# 19.2
# ____________
# 19.1
# ____________
# 18.6
# ____________
# 18.6
# ____________
# 18.5
# ____________
# 18.4
# ____________
# 18.3
# ____________
# 18.2
# ____________
# 18.1
# ____________
# 17.6
# ____________
# 17.5
# ____________
# 17.4
# ____________
# 17.3
# ____________
# 17.2
# ____________
# 17.1
# ____________

# %%
len(temp)
# Out:
# 31

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
from bs4 import BeautifulSoup
import urllib



driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
page_source = driver.page_source
data = BeautifulSoup(page_source, 'lxml')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})

control = "start"
for i in range(100):
    if control != "end":
        driver.execute_script("window.scrollBy(0,900)","")
        time.sleep(3)
        i = i+1
    if i == 6:
        control = "end"
        

print("OuTSIDE")
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_1640\1404724056.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# OuTSIDE

# %%
import re
from bs4 import BeautifulSoup
import urllib



page_source = driver.page_source
data = BeautifulSoup(page_source, 'lxml')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            j = i.parent
            j = j.parent
            j = j.parent
            j = j.parent
            j = j.parent
            k = j.find("span").text
            print(k)
            
            #print(j)
            print("____________")
            #print(type(i))

# %%
import re
from bs4 import BeautifulSoup
import urllib


def Control():

    url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
    webpage_content = urllib.request.urlopen(url).read()
    data = BeautifulSoup(webpage_content, 'html.parser')
    commentry = []
    runs = []
    temp = data.find_all("p",{"class":"ci-html-content"})
    for i in temp:
        if i.has_attr('class'):
            if 'ci-html-content' in i['class'] and len(i['class']) == 1:
                #print(i)
                j = i.parent
                j = j.parent
                j = j.parent
                j = j.parent
                j = j.parent
                k = j.find("span").text
                #print(k)
                #print("____________")
    b = float(k)
    return b


a = Control()
print(a)
print(type(a))
# Out:
# 17.1
# <class 'float'>

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
from bs4 import BeautifulSoup
import urllib


def Control(data):
    
    #data = BeautifulSoup(webpage_content, 'html.parser')
    commentry = []
    runs = []
    temp = data.find_all("p",{"class":"ci-html-content"})
    for i in temp:
        if i.has_attr('class'):
            if 'ci-html-content' in i['class'] and len(i['class']) == 1:
                #print(i)
                j = i.parent
                j = j.parent
                j = j.parent
                j = j.parent
                j = j.parent
                k = j.find("span").text
                #print(k)
                #print("____________")
    b = float(k)
    return b



driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
        
commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})

a = 0
b = 0.1
control = "start"
for i in range(25):
    if control != "end":
        driver.execute_script("window.scrollBy(0,700)","")
        print("scrolled")
        page_source = driver.page_source
        data = BeautifulSoup(page_source, 'lxml')
        a = Control(data)
        print("control return value",a)
        time.sleep(3)
        i = i+1
        print("i value",i)
        print("a value",a)
        print("b value",b)
        
    if  b == a:
        control = "end"

print("OuTSIDE")
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_1640\2063147606.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# scrolled
# control return value 17.1
# i value 1
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 2
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 3
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 4
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 5
# a value 17.1
# b value 0.1
# scrolled
# control return value 16.1
# i value 6
# a value 16.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 7
# a value 14.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 8
# a value 14.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 9
# a value 14.1
# b value 0.1
# scrolled
# control return value 12.1
# i value 10
# a value 12.1
# b value 0.1
# scrolled
# control return value 12.1
# i value 11
# a value 12.1
# b value 0.1
# scrolled
# control return value 10.1
# i value 12
# a value 10.1
# b value 0.1
# scrolled
# control return value 10.1
# i value 13
# a value 10.1
# b value 0.1
# scrolled
# control return value 8.1
# i value 14
# a value 8.1
# b value 0.1
# scrolled
# control return value 8.1
# i value 15
# a value 8.1
# b value 0.1
# scrolled
# control return value 6.1
# i value 16
# a value 6.1
# b value 0.1
# scrolled
# control return value 6.1
# i value 17
# a value 6.1
# b value 0.1
# scrolled
# control return value 4.1
# i value 18
# a value 4.1
# b value 0.1
# scrolled
# control return value 4.1
# i value 19
# a value 4.1
# b value 0.1
# scrolled
# control return value 2.1
# i value 20
# a value 2.1
# b value 0.1
# scrolled
# control return value 2.1
# i value 21
# a value 2.1
# b value 0.1
# scrolled
# control return value 0.1
# i value 22
# a value 0.1
# b value 0.1
# OuTSIDE

# %%
driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
page_source = driver.page_source
data = BeautifulSoup(page_source, 'lxml')

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
from bs4 import BeautifulSoup
import urllib
 
# create instance of Chrome webdriver
driver=webdriver.Chrome(ChromeDriverManager().install())
 
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
for i in range(10):
    driver.execute_script("window.scrollBy(0,700)","")
    time.sleep(3)
    i = i+1
page_source = driver.page_source

# url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
# webpage_content = urllib.request.urlopen(url).read()
# data = BeautifulSoup(webpage_content, 'html.parser')
data = BeautifulSoup(page_source, 'lxml')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            #print(type(i))
            commentry.append(i.get_text())
            j = i.parent
            b = j.previous_sibling
            #print(b)
            sp1 = b.find_all("span")
            for a in sp1:
                sp2 = a.find_all("span")
                for b in sp2:
                    runs.append(a.get_text())
                            
print(runs)
len(runs)
print("\n") 
print(commentry)

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
from bs4 import BeautifulSoup
import urllib


def Control(data):
    
    #data = BeautifulSoup(webpage_content, 'html.parser')
    commentry = []
    runs = []
    temp = data.find_all("p",{"class":"ci-html-content"})
    for i in temp:
        if i.has_attr('class'):
            if 'ci-html-content' in i['class'] and len(i['class']) == 1:
                #print(i)
                j = i.parent
                j = j.parent
                j = j.parent
                j = j.parent
                j = j.parent
                k = j.find("span").text
                #print(k)
                #print("____________")
    b = float(k)
    return b



driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary")
        
commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})

a = 0
b = 0.1
control = "start"
for i in range(25):
    if control != "end":
        driver.execute_script("window.scrollBy(0,700)","")
        print("scrolled")
        page_source = driver.page_source
        data = BeautifulSoup(page_source, 'lxml')
        a = Control(data)
        print("control return value",a)
        time.sleep(3)
        i = i+1
        print("i value",i)
        print("a value",a)
        print("b value",b)
        
    if  b == a:
        control = "end"

        
        
page_source = driver.page_source

# url="https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-new-zealand-33rd-match-group-1-1298167/ball-by-ball-commentary"
# webpage_content = urllib.request.urlopen(url).read()
# data = BeautifulSoup(webpage_content, 'html.parser')
data = BeautifulSoup(page_source, 'lxml')

commentry = []
runs = []
temp = data.find_all("p",{"class":"ci-html-content"})
#print(temp)
for i in temp:
    if i.has_attr('class'):
        if 'ci-html-content' in i['class'] and len(i['class']) == 1:
            #print(i)
            #print(type(i))
            commentry.append(i.get_text())
            j = i.parent
            b = j.previous_sibling
            #print(b)
            sp1 = b.find_all("span")
            for a in sp1:
                sp2 = a.find_all("span")
                for b in sp2:
                    runs.append(a.get_text())
                            
print(runs)
len(runs)
print("\n") 
print(commentry)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_1640\3727430586.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# scrolled
# control return value 17.1
# i value 1
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 2
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 3
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 4
# a value 17.1
# b value 0.1
# scrolled
# control return value 17.1
# i value 5
# a value 17.1
# b value 0.1
# scrolled
# control return value 16.1
# i value 6
# a value 16.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 7
# a value 14.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 8
# a value 14.1
# b value 0.1
# scrolled
# control return value 14.1
# i value 9
# a value 14.1
# b value 0.1
# scrolled
# control return value 12.1
# i value 10
# a value 12.1
# b value 0.1
# scrolled
# control return value 12.1
# i value 11
# a value 12.1
# b value 0.1
# scrolled
# control return value 10.1
# i value 12
# a value 10.1
# b value 0.1
# scrolled
# control return value 10.1
# i value 13
# a value 10.1
# b value 0.1
# scrolled
# control return value 8.1
# i value 14
# a value 8.1
# b value 0.1
# scrolled
# control return value 8.1
# i value 15
# a value 8.1
# b value 0.1
# scrolled
# control return value 6.1
# i value 16
# a value 6.1
# b value 0.1
# scrolled
# control return value 6.1
# i value 17
# a value 6.1
# b value 0.1
# scrolled
# control return value 4.1
# i value 18
# a value 4.1
# b value 0.1
# scrolled
# control return value 4.1
# i value 19
# a value 4.1
# b value 0.1
# scrolled
# control return value 2.1
# i value 20
# a value 2.1
# b value 0.1
# scrolled
# control return value 2.1
# i value 21
# a value 2.1
# b value 0.1
# scrolled
# control return value 0.1
# i value 22
# a value 0.1
# b value 0.1
# ['Sam Curran to Santner, 1 run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, no run', 'Sam Curran to Santner, 2 runs', 'Sam Curran to Santner, 1 wide', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Sodhi, no run', 'Woakes to Santner, SIX runs', 'Woakes to Santner, 1 wide', 'Woakes to Santner, 2 runs', 'Woakes to Santner, 2 runs', 'Woakes to Sodhi, 1 leg bye', 'Woakes to Santner, 1 run', 'Woakes to Sodhi, 1 run', 'Sam Curran to Sodhi, 1 run', 'Sam Curran to Santner, 1 run', 'Sam Curran to Sodhi, 3 runs', 'Sam Curran to Phillips, OUT', 'Sam Curran to Santner, 1 run', 'Sam Curran to Phillips, 3 runs', 'Woakes to Mitchell, OUT', 'Woakes to Phillips, 1 run', 'Woakes to Phillips, no run', 'Woakes to Mitchell, 1 run', 'Woakes to Mitchell, 2 runs', 'Woakes to Phillips, 1 run', 'Wood to Mitchell, no run', 'Wood to Mitchell, no run', 'Wood to Neesham, OUT', 'Wood to Neesham, 2 runs', 'Wood to Phillips, 1 run', 'Wood to Phillips, no run', 'Stokes to Neesham, FOUR runs', 'Stokes to Williamson, OUT', 'Stokes to Phillips, 1 run', 'Stokes to Phillips, no run', 'Stokes to Phillips, FOUR runs', 'Stokes to Williamson, 1 run', 'Rashid to Williamson, 1 run', 'Rashid to Phillips, 1 run', 'Rashid to Phillips, 2 runs', 'Rashid to Phillips, SIX runs', 'Rashid to Phillips, SIX runs', 'Rashid to Williamson, 1 run', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Phillips, no run', 'Sam Curran to Phillips, 2 runs', 'Sam Curran to Williamson, 1 run', 'Sam Curran to Phillips, 2 wide', 'Sam Curran to Williamson, 1 run', 'Wood to Williamson, 1 run', 'Wood to Phillips, 1 run', 'Wood to Phillips, no run', 'Wood to Phillips, SIX runs', 'Wood to Phillips, no run', 'Wood to Phillips, 2 runs', 'Livingstone to Williamson, no run', 'Livingstone to Williamson, 2 runs', 'Livingstone to Phillips, 1 run', 'Livingstone to Phillips, FOUR runs', 'Livingstone to Williamson, 1 run', 'Livingstone to Williamson, 2 runs', 'Rashid to Williamson, 1 run', 'Rashid to Phillips, 1 run', 'Rashid to Williamson, 1 run', 'Rashid to Williamson, no run', 'Rashid to Phillips, 1 run', 'Rashid to Phillips, no run', 'Livingstone to Williamson, FOUR runs', 'Livingstone to Williamson, no run', 'Livingstone to Phillips, 1 run', 'Livingstone to Williamson, 1 run', 'Livingstone to Williamson, 2 runs', 'Livingstone to Phillips, 1 run', 'Rashid to Williamson, 2 runs', 'Rashid to Williamson, no run', 'Rashid to Phillips, 1 run', 'Rashid to Phillips, 2 runs', 'Rashid to Williamson, 1 run', 'Rashid to Williamson, no run', 'Livingstone to Phillips, FOUR runs', 'Livingstone to Williamson, 1 run', 'Livingstone to Phillips, 1 run', 'Livingstone to Phillips, no run', 'Livingstone to Williamson, 1 run', 'Livingstone to Williamson, no run', 'Wood to Phillips, FOUR runs', 'Wood to Williamson, 1 run', 'Wood to Williamson, no run', 'Wood to Williamson, FOUR runs', 'Wood to Williamson, no run', 'Wood to Williamson, 1 wide', 'Wood to Williamson, 2 runs', 'Sam Curran to Allen, OUT', 'Sam Curran to Allen, no run', 'Sam Curran to Williamson, 1 run', 'Sam Curran to Williamson, no run', 'Sam Curran to Allen, 1 run', 'Sam Curran to Allen, no run', 'Woakes to Williamson, FOUR runs', 'Woakes to Williamson, no run', 'Woakes to Williamson, no run', 'Woakes to Allen, 1 run', 'Woakes to Allen, SIX runs', 'Woakes to Williamson, 1 run', 'Rashid to Williamson, 1 run', 'Rashid to Williamson, no run', 'Rashid to Allen, 3 runs', 'Rashid to Williamson, 1 run', 'Rashid to Williamson, no run', 'Rashid to Allen, 1 run', 'Woakes to Conway, OUT', 'Woakes to Conway, no run', 'Woakes to Allen, 1 run', 'Woakes to Conway, 1 leg bye', 'Woakes to Conway, 2 runs', 'Woakes to Conway, no run', 'Moeen Ali to Conway, 1 run', 'Moeen Ali to Conway, no run', 'Moeen Ali to Conway, no run', 'Moeen Ali to Conway, no run', 'Moeen Ali to Allen, 1 run', 'Moeen Ali to Allen, 2 runs']
#
#
# ['right on the mark again from Curran, bending back in on a yorker length, clipped to long-on, and England win by 20 runs', 'bouncer, well directed, following the batter and rising sharply off the deck. More precious dots to improve the NRR for England', "brilliant blockhole bowling from Curran, another inswinging yorker, curling into the left-hander's toes", 'inswinger, into the legs, cuffed to long-on, and back for two more', "fired in fuller, Santner walks across his stumps, and England review! Looked like the umpire was going to signal wide, but there might have been a tickle through to the keeper. Doesn't look like it... and no pad either. Wide it is!", 'outside off, into the pitch, back of a length, clawed to midwicket', "ghosts past the outside edge, curling away on the full length, can't connect on the slapped drive. A precious dot, given that NRR is as important as the win now", "sits back in the crease, and slams a six up and over long-on! A useful strike from Santner, just keeps New Zealand's faint hopes alive. Woakes is frustrated, but that's a mighty stint all the same", "too wide this time, outside the batter's arc", 'back of a length, tight across the left-hander, another attempted pull but rolls out towards long-on.', 'crashed on the up, full length outside off, and picked up in the deep', 'good aggression from Woakes, pace on this time, into the pitch as the batter advances and wears his attempted pull in the ribs', 'pushed across the left-hander on the full length, hacked out to deep point and just the single, as the rate leaps towards four a ball', 'thumped through the line, but no timing, another single to mid-on', "eased down the ground, another exceptional screw-turning over. It's 20 an over now, and New Zealand need snookers", 'superb from Curran, sees the batter shaping to leg, follows him with the inswinger, and they can only pick off the cramped single to mid-on', 'stabbed off the ribs, up and over backward square, Rashid rushes back at the rope and drags it back well', 'Walloped high through the line, and Jordan pouches another! That, surely, is the game for England! Phillips had to put bat through ball, but the tricksy angle and pace off the pitch scuppers his timing. The super-sub is back on the edge of the rope and makes no mistake!', 'short from Curran, sticking in the pitch as Santner leans back on a pull to midwicket', "outside off, slams the drive with excellent placement, but Brook tracks it from deep cover and flings out a hand to intercept! Brilliant commitment to save a single. Still, that's the three a ball needed...", "Slower ball, launched through the line but Jordan's there at long-on! What a brilliant over from Woakes, into the pitch once again, just back of a length, confounding Mitchell's timing as he swung for the hills. Suddenly, it's Phillips or bust for New Zealand!", 'pace off again, short and into the ribs, another muscular fling of the bat but only a single to backward square', 'another outstanding cutter, line and length, gripping the surface, turning the screw, jabbed back through the line for a precious dot', "slower ball, into the pitch, brings out the pull but it's a long way to the rope and just another single", 'back of a length, wide on the crease again, another tuck behind square and though Curran releases quickly, Buttler has to stretch to flick it back onto the stumps. Safely home', 'hits the pitch with the cutter, wide of the crease, defended out to the off side', 'whips through the pull, but misses! Wood has delivered with a priceless over. One more up his sleeve to drag England back into this contest', 'fast and full, outside off, angled bat on the defensive push to point', "pulled... straight to Curran at deep midwicket! The pace makes the breakthrough! Short, outside off, Neesham rocks back, targetting the longer side of the ground, but can't get hold of it. Curran rushes in, steadies himself, and gees up the crowd as England continue to battle back!", 'round  ...

# %%
len(commentry)
# Out:
# 124
